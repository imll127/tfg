# %%
# !pip install gpytorch
# Out:
# Collecting gpytorch
#   Downloading gpytorch-1.14.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jaxtyping (from gpytorch)
#   Downloading jaxtyping-0.3.4-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.12/dist-packages (from gpytorch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from gpytorch) (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from gpytorch) (1.16.3)
# Collecting linear_operator>=0.6 (from gpytorch)
#   Downloading linear_operator-0.6-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from linear_operator>=0.6->gpytorch) (2.9.0+cpu)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy>=1.6.0->gpytorch) (2.0.2)
# Collecting wadler-lindig>=0.1.3 (from jaxtyping->gpytorch)
#   Downloading wadler_lindig-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->gpytorch) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->gpytorch) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch) (2025.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->linear_operator>=0.6->gpytorch) (3.0.3)
# Downloading gpytorch-1.14.3-py3-none-any.whl (280 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.6/280.6 kB 6.2 MB/s eta 0:00:00
# Downloading linear_operator-0.6-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.3/176.3 kB 13.3 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.4-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 3.8 MB/s eta 0:00:00
# Downloading wadler_lindig-0.1.7-py3-none-any.whl (20 kB)
# Installing collected packages: wadler-lindig, jaxtyping, linear_operator, gpytorch
# Successfully installed gpytorch-1.14.3 jaxtyping-0.3.4 linear_operator-0.6 wadler-lindig-0.1.7

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt

# %matplotlib inline

def f(x):
    return (1 - x/2)**2


def g(x):
  return torch.sin(2*math.pi*x)


# Training data is 100 points in [0,1] inclusive regularly spaced
train_x = torch.linspace(-1, 1, 40)
# True function is sin(2*pi*x) with Gaussian noise
train_y = f(train_x)




class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)



likelihood = gpytorch.likelihoods.GaussianLikelihood( noise_constraint=gpytorch.constraints.GreaterThan(1e-8))

likelihood.noise = torch.tensor(1e-8)
likelihood.raw_noise.requires_grad_(False) #para no optimizar el ruido

model = ExactGPModel(train_x, train_y, likelihood)

# %%
import os
smoke_test = ('CI' in os.environ)
training_iter = 2 if smoke_test else 50

model.train()
likelihood.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)


for i in range(training_iter):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))

    optimizer.step()
# Out:
# /usr/local/lib/python3.12/dist-packages/linear_operator/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/linear_operator/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-05 to the diagonal
#   warnings.warn(
# Iter 1/50 - Loss: -4.667   lengthscale: 0.693   noise: 0.000
# Iter 2/50 - Loss: -4.725   lengthscale: 0.744   noise: 0.000
# Iter 3/50 - Loss: -4.779   lengthscale: 0.798   noise: 0.000
# Iter 4/50 - Loss: -4.820   lengthscale: 0.853   noise: 0.000
# Iter 5/50 - Loss: -4.871   lengthscale: 0.911   noise: 0.000
# Iter 6/50 - Loss: -4.890   lengthscale: 0.970   noise: 0.000
# Iter 7/50 - Loss: -4.942   lengthscale: 1.030   noise: 0.000
# Iter 8/50 - Loss: -4.982   lengthscale: 1.092   noise: 0.000
# Iter 9/50 - Loss: -5.002   lengthscale: 1.154   noise: 0.000
# Iter 10/50 - Loss: -5.017   lengthscale: 1.216   noise: 0.000
# Iter 11/50 - Loss: -5.042   lengthscale: 1.278   noise: 0.000
# Iter 12/50 - Loss: -5.067   lengthscale: 1.339   noise: 0.000
# Iter 13/50 - Loss: -5.069   lengthscale: 1.401   noise: 0.000
# Iter 14/50 - Loss: -5.089   lengthscale: 1.461   noise: 0.000
# Iter 15/50 - Loss: -5.096   lengthscale: 1.520   noise: 0.000
# Iter 16/50 - Loss: -5.116   lengthscale: 1.578   noise: 0.000
# Iter 17/50 - Loss: -5.130   lengthscale: 1.634   noise: 0.000
# Iter 18/50 - Loss: -5.116   lengthscale: 1.689   noise: 0.000
# Iter 19/50 - Loss: -5.128   lengthscale: 1.742   noise: 0.000
# Iter 20/50 - Loss: -5.131   lengthscale: 1.794   noise: 0.000
# Iter 21/50 - Loss: -5.183   lengthscale: 1.844   noise: 0.000
# Iter 22/50 - Loss: -5.140   lengthscale: 1.893   noise: 0.000
# Iter 23/50 - Loss: -5.146   lengthscale: 1.940   noise: 0.000
# Iter 24/50 - Loss: -5.202   lengthscale: 1.986   noise: 0.000
# Iter 25/50 - Loss: -5.244   lengthscale: 2.030   noise: 0.000
# Iter 26/50 - Loss: -4.143   lengthscale: 2.072   noise: 0.000
# Iter 27/50 - Loss: -5.229   lengthscale: 2.112   noise: 0.000
# Iter 28/50 - Loss: -4.147   lengthscale: 2.150   noise: 0.000
# Iter 29/50 - Loss: -4.150   lengthscale: 2.186   noise: 0.000
# Iter 30/50 - Loss: -5.236   lengthscale: 2.219   noise: 0.000
# Iter 31/50 - Loss: -4.154   lengthscale: 2.250   noise: 0.000
# Iter 32/50 - Loss: -5.245   lengthscale: 2.279   noise: 0.000
# Iter 33/50 - Loss: -5.270   lengthscale: 2.307   noise: 0.000
# Iter 34/50 - Loss: -4.154   lengthscale: 2.335   noise: 0.000
# Iter 35/50 - Loss: -4.158   lengthscale: 2.361   noise: 0.000
# Iter 36/50 - Loss: -4.160   lengthscale: 2.384   noise: 0.000
# Iter 37/50 - Loss: -4.160   lengthscale: 2.406   noise: 0.000
# Iter 38/50 - Loss: -4.159   lengthscale: 2.425   noise: 0.000
# Iter 39/50 - Loss: -4.159   lengthscale: 2.444   noise: 0.000
# Iter 40/50 - Loss: -4.161   lengthscale: 2.461   noise: 0.000
# Iter 41/50 - Loss: -4.161   lengthscale: 2.476   noise: 0.000
# Iter 42/50 - Loss: -4.163   lengthscale: 2.490   noise: 0.000
# Iter 43/50 - Loss: -4.161   lengthscale: 2.504   noise: 0.000
# Iter 44/50 - Loss: -4.164   lengthscale: 2.516   noise: 0.000
# Iter 45/50 - Loss: -4.164   lengthscale: 2.528   noise: 0.000
# Iter 46/50 - Loss: -4.167   lengthscale: 2.539   noise: 0.000
# Iter 47/50 - Loss: -4.166   lengthscale: 2.549   noise: 0.000
# Iter 48/50 - Loss: -5.289   lengthscale: 2.559   noise: 0.000
# Iter 49/50 - Loss: -4.165   lengthscale: 2.569   noise: 0.000
# Iter 50/50 - Loss: -4.171   lengthscale: 2.578   noise: 0.000

# %%
# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(-1, 1, 51)
    observed_pred = likelihood(model(test_x))


with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, figsize=(8, 8))

    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-3, 3])
    ax.legend(['Observed Data', 'Mean', 'Confidence'])
# Out:
# /usr/local/lib/python3.12/dist-packages/gpytorch/distributions/multivariate_normal.py:376: NumericalWarning: Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-06.
#   warnings.warn(

# %% [markdown]
# SOLVE PDE

# %%
torch.manual_seed(0)

# PDE: u'' = 2


# Boundary conditions
x_bc = torch.tensor([[-1.0], [1.0]])
y_bc = torch.tensor([9/4, 1/4])

# Collocation points (for PDE residual)
x_col = torch.linspace(-1, 1, 80).unsqueeze(-1)
x_col.requires_grad_(True)

x_int = train_x.unsqueeze(-1)   # [40, 1]
y_int = train_y                 # [40]

x_train = torch.cat([x_bc, x_int], dim=0)   # [42, 1]
y_train = torch.cat([y_bc, y_int], dim=0)   # [42]

# %%
model = ExactGPModel(x_train, y_train, likelihood)

# %%
model.train()
likelihood.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.05)
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(300):
    optimizer.zero_grad()

    # Boundary condition loss
    output = model(x_train)
    loss_data = -mll(output, y_train)

    # PDE residual loss (must be in eval mode)
    model.eval()
    output_col = model(x_col)
    model.train()

    u = output_col.mean

    du_dx = torch.autograd.grad(
        u, x_col,
        grad_outputs=torch.ones_like(u),
        create_graph=True
    )[0]

    d2u_dx2 = torch.autograd.grad(
        du_dx, x_col,
        grad_outputs=torch.ones_like(du_dx),
        create_graph=True
    )[0]

    residual = d2u_dx2 - 2.0
    loss_pde = (residual**2).mean()

    loss = loss_data +  10* loss_pde
    loss.backward()
    optimizer.step()

# %%
model.eval()
likelihood.eval()

x_test = torch.linspace(-1, 1, 200)

with torch.no_grad():
    pred = likelihood(model(x_test))
    mean = pred.mean
    lower, upper = pred.confidence_region()

# Exact solution
u_exact =( x_test.squeeze()- 0.5)**2

plt.figure(figsize=(8,5))
plt.plot(x_test.numpy(), u_exact.numpy(), 'k--', label='Exact')
plt.plot(x_test.numpy(), mean.numpy(), 'b', label='GP mean')
plt.fill_between(
    x_test.squeeze().numpy(),
    lower.numpy(),
    upper.numpy(),
    alpha=0.3
)
plt.scatter(x_bc.numpy(), y_bc.numpy(), c='red', zorder=5, label='BC')
plt.legend()
plt.xlabel("x")
plt.ylabel("u(x)")
plt.title("GP solution of u'' = 2")
plt.show()

# %% [markdown]
# otro approach

# %%
def rbf_kernel(x, xp, lengthscale=0.5, variance=1.0):
    r = (x - xp.T) ** 2
    return variance * torch.exp(-0.5 * r / lengthscale**2)

def d2_rbf_dx2(x, xp, lengthscale=0.5, variance=1.0):
    k = rbf_kernel(x, xp, lengthscale, variance)
    return k * ((x - xp.T)**2 / lengthscale**4 - 1.0 / lengthscale**2)

def d2d2_rbf(x, xp, lengthscale=0.5, variance=1.0):
    k = rbf_kernel(x, xp, lengthscale, variance)
    r2 = (x - xp.T)**2
    l2 = lengthscale**2
    return k * (r2**2 / l2**4 - 6*r2 / l2**3 + 3 / l2**2)

# %%
x_u = torch.tensor([[-1.0], [1.0]])
y_u = torch.tensor([[9/4], [1/4]]) #boundary conditions

x_f = torch.linspace(-1, 1, 20).unsqueeze(-1)
y_f = 2.0 * torch.ones_like(x_f)

# %%
l = 0.4
var = 1.0
noise = 1e-6

K_uu = rbf_kernel(x_u, x_u, l, var)
K_uf = d2_rbf_dx2(x_u, x_f, l, var)
K_fu = K_uf.T
K_ff = d2d2_rbf(x_f, x_f, l, var)


K = torch.cat([torch.cat([K_uu, K_uf], dim=1),torch.cat([K_fu, K_ff], dim=1)], dim=0)

# %%
y = torch.cat([y_u, y_f], dim=0)
x_star = torch.linspace(-1, 1, 200).unsqueeze(-1)

K_su = rbf_kernel(x_star, x_u, l, var)
K_sf = d2_rbf_dx2(x_star, x_f, ++ l, var)
K_s = torch.cat([K_su, K_sf], dim=1)

K_ss = rbf_kernel(x_star, x_star, l, var)

alpha = torch.linalg.solve(K, y)
mean = K_s @ alpha

cov = K_ss - K_s @ torch.linalg.solve(K, K_s.T)
std = torch.sqrt(torch.diag(cov))

# %%
u_exact = x_star.squeeze()**2 - x_star.squeeze() + 0.25
plt.figure(figsize=(8,5))
plt.plot(x_star, u_exact, 'k--', label='Exact')
plt.plot(x_star, mean, 'b', label='GP mean')
plt.fill_between(
    x_star.squeeze(),
    (mean.squeeze() - 2*std),
    (mean.squeeze() + 2*std),
    alpha=0.3
)
plt.scatter(x_u, y_u, c='red', label='BC')
plt.legend()
plt.xlabel("x")
plt.ylabel("u(x)")
plt.title("GP  solution of u''=2")
plt.show()

# %%
def rbf(x, xp, l, var):
    # x: (N,1), xp: (M,1)
    r2 = (x - xp.T) ** 2
    return var * torch.exp(-0.5 * r2 / (l**2))

def d2_rbf_dx2(x, xp, l, var):
    # second derivative w.r.t. the variable x (lo mismo que para xp)
    k = rbf(x, xp, l, var)
    r2 = (x - xp.T) ** 2
    l2 = l**2
    return k * (r2 / (l2**2) - 1.0 / l2)

def d2d2_rbf(x, xp, l, var):
    # d^2/dx^2 d^2/dxp^2 k(x,xp)
    k = rbf(x, xp, l, var)
    r2 = (x - xp.T) ** 2
    l2 = l**2
    return k * (r2**2 / (l2**4) - 6.0 * r2 / (l2**3) + 3.0 / (l2**2))


#  task 0 = u, task 1 = u''
class DerRBFKernel(gpytorch.kernels.Kernel):
    is_stationary = True

    def __init__(self, init_lengthscale=0.4, init_variance=1.0):
        super().__init__()
        self.base_kernel= gpytorch.kernels.RBFKernel()
        self.outputscale = gpytorch.kernels.ScaleKernel(self.base_kernel)

    def forward(self, x1, x2, diag=False, **params):
        # x1, x2: (N,2) and (M,2) with [:,0]=location, [:,1]=task
        x1_loc = x1[:, 0:1] #primera columna (N,1)
        x2_loc = x2[:, 0:1]
        t1 = x1[:, 1].long()  # (N,)
        t2 = x2[:, 1].long()  # (M,)

        l = self.base_kernel.lengthscale
        var = self.outputscale.outputscale


        # Base and derivative blocks
        K00 = self.outputscale(x1_loc, x2_loc).to_dense() #coge el kernel y lo trnasforma en matriz
        K10 = d2_rbf_dx2(x1_loc, x2_loc, l, var)      # d^2/dx^2 k
        K01 = d2_rbf_dx2(x1_loc, x2_loc, l, var)      # d^2/dx'^2 k (same formula for RBF)
        K11 = d2d2_rbf(x1_loc, x2_loc, l, var)

        # Assemble according to task pairs
        # masks: (N,M)
        t1m = t1[:, None]
        t2m = t2[None, :]

        mask00 = (t1m == 0) & (t2m == 0)
        mask01 = (t1m == 0) & (t2m == 1)
        mask10 = (t1m == 1) & (t2m == 0)
        mask11 = (t1m == 1) & (t2m == 1)

        K = torch.zeros_like(K00)
        K = K + mask00 * K00
        K = K + mask01 * K01
        K = K + mask10 * K10
        K = K + mask11 * K11

        return K

# ---------- Exact GP model ----------
class ExactGP(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super().__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ZeroMean()
        self.covar_module = DerRBFKernel(init_lengthscale=0.4, init_variance=1.0)

    def forward(self, x):
        mean_x = self.mean_module(x[:, 0:1])
        covar_x = self.covar_module(x, x)
        return gpytorch.distributions.MultivariateNormal(mean_x.squeeze(-1), covar_x)


# ---------- Build training data: boundary u and interior u'' ----------
torch.manual_seed(0)

# boundary points
x_u = torch.tensor([[-1.0], [1.0]])
y_u = torch.tensor([9/4, 1/4], dtype=torch.float32)  # (2,)

# PDE points
x_f = torch.linspace(-1, 1, 20).unsqueeze(-1)
y_f = 2.0 * torch.ones(x_f.shape[0], dtype=torch.float32)  # (20,)

# inputs are [x, task]
Xu = torch.cat([x_u, torch.zeros_like(x_u)], dim=1)  # task=0
Xf = torch.cat([x_f, torch.ones_like(x_f)], dim=1)   # task=1

train_x = torch.cat([Xu, Xf], dim=0)                 # (22,2)
train_y = torch.cat([y_u, y_f], dim=0)               # (22,)


# ---------- Train ----------
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGP(train_x, train_y, likelihood)

model.train()
likelihood.train()

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 200
for i in range(training_iter):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()

# Predict u(x*) (task=0)
model.eval()
likelihood.eval()

x_star = torch.linspace(-1, 1, 200).unsqueeze(-1)
X_star_u = torch.cat([x_star, torch.zeros_like(x_star)], dim=1)  # task=0 (u)

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    pred = likelihood(model(X_star_u))
    mean_u = pred.mean
    lower_u, upper_u = pred.confidence_region()

print(
    "Trained lengthscale:",
    model.covar_module.base_kernel.lengthscale.item()
)
print(
    "Trained variance:",
    model.covar_module.outputscale.outputscale.item()
)
print(
    "Noise:",
    likelihood.noise.item()
)


# mean_u is the mean for u(x)
# Out:
# Trained lengthscale: 1.628942608833313
# Trained variance: 11.694389343261719
# Noise: 0.00010499785275897011

# %%
plt.plot(x_star.squeeze(), mean_u, label="u(x)")
plt.scatter(x_u.squeeze(), y_u, color="black")
plt.xlabel("x")
plt.ylabel("u(x)")
plt.legend()
plt.show()
